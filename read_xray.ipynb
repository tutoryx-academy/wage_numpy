# %%
import imageio

# %%
xray_image = imageio.v3.imread('sample_x_ray.png')

# %%
xray_image.shape
# Out:
# (464, 462, 3)

# %%
import matplotlib.pyplot as plt

plt.imshow(xray_image, cmap='gray')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(461.5), np.float64(463.5), np.float64(-0.5))

# %%
from scipy import ndimage

xray_image_gausaian = ndimage.gaussian_laplace(xray_image, sigma=1)

plt.imshow(xray_image_gausaian)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(461.5), np.float64(463.5), np.float64(-0.5))

# %%
xray_image.shape
# Out:
# (464, 462, 3)

# %%
xray_image[:,:,0]
# Out:
# array([[165,  76,  76, ...,  76,  76,  76],
#        [127,   1,   1, ...,   1,   1,   1],
#        [127,   1,   1, ...,   1,   1,   1],
#        ...,
#        [152,  50,  50, ...,  13,  12,  11],
#        [202, 150, 150, ..., 132, 132, 132],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
xray_image[:,:,1]
# Out:
# array([[165,  76,  76, ...,  76,  76,  76],
#        [127,   1,   1, ...,   1,   1,   1],
#        [127,   1,   1, ...,   1,   1,   1],
#        ...,
#        [152,  50,  50, ...,  13,  12,  11],
#        [202, 150, 150, ..., 132, 132, 132],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
xray_image[:,:,2]
# Out:
# array([[165,  76,  76, ...,  76,  76,  76],
#        [127,   1,   1, ...,   1,   1,   1],
#        [127,   1,   1, ...,   1,   1,   1],
#        ...,
#        [152,  50,  50, ...,  13,  12,  11],
#        [202, 150, 150, ..., 132, 132, 132],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
plt.imshow(xray_image[20:150,150:300,:])

# %%
cropped_image = xray_image[20:150,150:300,:]
cropped_image
# Out:
# array([[[ 59,  59,  59],
#         [ 61,  61,  61],
#         [ 64,  64,  64],
#         ...,
#         [154, 154, 154],
#         [153, 153, 153],
#         [151, 151, 151]],
#
#        [[ 62,  62,  62],
#         [ 65,  65,  65],
#         [ 67,  67,  67],
#         ...,
#         [155, 155, 155],
#         [154, 154, 154],
#         [152, 152, 152]],
#
#        [[ 66,  66,  66],
#         [ 68,  68,  68],
#         [ 70,  70,  70],
#         ...,
#         [156, 156, 156],
#         [154, 154, 154],
#         [153, 153, 153]],
#
#        ...,
#
#        [[149, 149, 149],
#         [148, 148, 148],
#         [143, 143, 143],
#         ...,
#         [137, 137, 137],
#         [136, 136, 136],
#         [141, 141, 141]],
#
#        [[148, 148, 148],
#         [147, 147, 147],
#         [143, 143, 143],
#         ...,
#         [134, 134, 134],
#         [134, 134, 134],
#         [139, 139, 139]],
#
#        [[147, 147, 147],
#         [146, 146, 146],
#         [143, 143, 143],
# ...

# %%
cropped_image * 2
# Out:
# array([[[118, 118, 118],
#         [122, 122, 122],
#         [128, 128, 128],
#         ...,
#         [ 52,  52,  52],
#         [ 50,  50,  50],
#         [ 46,  46,  46]],
#
#        [[124, 124, 124],
#         [130, 130, 130],
#         [134, 134, 134],
#         ...,
#         [ 54,  54,  54],
#         [ 52,  52,  52],
#         [ 48,  48,  48]],
#
#        [[132, 132, 132],
#         [136, 136, 136],
#         [140, 140, 140],
#         ...,
#         [ 56,  56,  56],
#         [ 52,  52,  52],
#         [ 50,  50,  50]],
#
#        ...,
#
#        [[ 42,  42,  42],
#         [ 40,  40,  40],
#         [ 30,  30,  30],
#         ...,
#         [ 18,  18,  18],
#         [ 16,  16,  16],
#         [ 26,  26,  26]],
#
#        [[ 40,  40,  40],
#         [ 38,  38,  38],
#         [ 30,  30,  30],
#         ...,
#         [ 12,  12,  12],
#         [ 12,  12,  12],
#         [ 22,  22,  22]],
#
#        [[ 38,  38,  38],
#         [ 36,  36,  36],
#         [ 30,  30,  30],
# ...

# %%
plt.imshow(cropped_image * 2)

# %%
import numpy as np

# %%
cropped_image_red = cropped_image[:,:,0]
np.savetxt('image.csv',cropped_image_red, fmt='%.0f')

# %%
image_array_load = np.loadtxt('image.csv')
image_array_load
# Out:
# array([[ 59.,  61.,  64., ..., 154., 153., 151.],
#        [ 62.,  65.,  67., ..., 155., 154., 152.],
#        [ 66.,  68.,  70., ..., 156., 154., 153.],
#        ...,
#        [149., 148., 143., ..., 137., 136., 141.],
#        [148., 147., 143., ..., 134., 134., 139.],
#        [147., 146., 143., ..., 131., 131., 136.]])

# %%
plt.imshow(image_array_load)
